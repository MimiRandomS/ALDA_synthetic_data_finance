# %%
from finance_generator.generator import generate_client_info

df = generate_client_info(10)
print(df.head())
print(df["age"].describe())
# Out:
#       client_id first_name  last_name  age date_of_birth  \
# 0  CLI-33FC084A   Kimberly  Velasquez   52    1973-04-25
# 1  CLI-43B161B6      Brian    Jackson   38    1987-08-24
# 2  CLI-5109A715      Aaron      Mills   34    1991-05-08
# 3  CLI-F8215B87      Megan    Spencer   51    1975-03-01
# 4  CLI-610EF0A2  Frederick      James   33    1992-11-30
#
#                          email                 phone    country
# 0  anthonyrichards@example.net       +34872 62 08 90      Spain
# 1         danaford@example.net     494.512.9448x1256       Peru
# 2    nicholasscott@example.net      +54 15 2817 3129  Argentina
# 3      laurabrewer@example.com  001-646-940-3212x332       Peru
# 4   hernandezdavid@example.org            9623680691    Uruguay
# count    10.000000
# mean     41.000000
# std       8.313309
# min      26.000000
# 25%      35.000000
# 50%      42.000000
# 75%      46.500000
# max      52.000000
# Name: age, dtype: float64
